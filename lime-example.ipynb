# %%
import cv2 as cv
import sys
import os

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
from algorithms import lime

# %%
raw_image = cv.imread("images/test-img.jpg")
raw_image = cv.cvtColor(raw_image, cv.COLOR_BGR2RGB)
plt.figure(figsize=(16,4))
plt.imshow(raw_image)

# %%
img_ws1 = lime.lime(raw_image, weight_strategy=1)

# %%
plt.figure(figsize=(16,4))
plt.imshow(img_ws1)
